# %%
import numpy as p
import matplotlib.pyplot as mp
# %matplotlib inline

# %%
import cv2

# %%
hell= cv2.imread('man.jpg')

# %%
type(hell)
# Out:
# numpy.ndarray

# %%
hell
# Out:
# array([[[217, 254, 246],
#         [217, 254, 246],
#         [217, 254, 246],
#         ...,
#         [217, 254, 246],
#         [217, 254, 246],
#         [217, 254, 246]],
#
#        [[217, 254, 246],
#         [217, 254, 246],
#         [217, 254, 246],
#         ...,
#         [217, 254, 246],
#         [217, 254, 246],
#         [217, 254, 246]],
#
#        [[217, 254, 246],
#         [217, 254, 246],
#         [217, 254, 246],
#         ...,
#         [217, 254, 246],
#         [217, 254, 246],
#         [217, 254, 246]],
#
#        ...,
#
#        [[207, 254, 245],
#         [207, 254, 245],
#         [207, 254, 245],
#         ...,
#         [208, 253, 244],
#         [208, 253, 244],
#         [208, 253, 244]],
#
#        [[212, 253, 245],
#         [211, 254, 245],
#         [211, 254, 245],
#         ...,
#         [210, 253, 244],
#         [210, 253, 244],
#         [210, 253, 244]],
#
#        [[212, 253, 245],
#         [211, 254, 245],
#         [211, 254, 245],
# ...

# %%
mp.imshow(hell)

# %%
fiximage =  cv2.cvtColor(hell,cv2.COLOR_BGR2RGB)

# %%
mp.imshow(fiximage)

# %%
imggrey = cv2.imread('man.jpg',cv2.IMREAD_GRAYSCALE)

# %%
mp.imshow(imggrey)

# %%
resize = cv2.resize(fiximage,(100,200))

# %%
mp.imshow(resize)

# %%
resize.shape
# Out:
# (200, 100, 3)

# %%
w_ration = 0.8
h_ratio =  0.2

# %%
mp.imshow(fiximage)

# %%
new_img = cv2.flip(fiximage,0)
mp.imshow(new_img)

# %%
cv2.imwrite(' ')
