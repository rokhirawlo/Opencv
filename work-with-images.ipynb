# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('rainbow.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (194, 259, 3)

# %%
plt.imshow(img)

# %%
# matplotli--> RGB RED GREEN BLUE
#  OPENcv  BLUE GREEN RED

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('dog.jpg')

# %%
#changing into grayscale

plt.imshow(img_gray, cmap = 'gray')

# %%
img_gray.shape
# Out:
# (351, 620, 3)

# %%
#resizing the image 
    new_img = cv2.resize(fix_img,(200,300))

# %%
plt.imshow(new_img)

# %%
#reducing image by their ratio
w_ratio = 0.5
h_ratio = 0.2

# %%
new_img2 = cv2.resize(new_img,(0,0),new_img, w_ratio,h_ratio)

# %%
plt.imshow(new_img2)

# %%
# for flipping the imgage
# axis 0 for horizontal, 1for verticlal -1 for upper horizontal

img_gray = cv2.flip(img_gray,0)
plt.imshow(img_gray)

# %%
# for writing the image or for aving the image 

#cv2.imwrite('totally_new.jpg', img_gray)

# %%
# for displaying on window using the open cv2  

import cv2
  
img = cv2.imread('dog.jpg')
cv2.imshow('Pupy', img)
cv2.waitKey()
# Out:
# -1
