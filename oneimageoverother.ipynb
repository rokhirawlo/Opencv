# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import cv2

# %%
img1 = cv2.imread('dog.jpg')
new1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2 =  cv2.imread('opencv.png') 
new2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
new1.shape
# Out:
# (351, 620, 3)

# %%
new2.shape
# Out:
# (500, 500, 3)

# %%
new2 =  cv2.resize(img2,(200,200))

# %%
new2.shape
# Out:
# (200, 200, 3)

# %%
new1 = cv2.resize(img1, (934,1400))

# %%
new1.shape
# Out:
# (1400, 934, 3)

# %%
new2 = cv2.resize(img2,(100,200))

# %%
plt.imshow(new1)

# %%
new2.shape
# Out:
# (200, 100, 3)

# %%
x_offset = 934 - 600
y_offset = 1400 -600

# %%
roi = new1[y_offset:1400,x_offset:934]

# %%
plt.imshow(roi)

# %%
img2gray = cv2.cvtColor(new2, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(img2gray,cmap ='gray')

# %%
mask_inv = cv2.bitwise_not(img2gray)

# %%
plt.imshow(mask_inv, cmap ='gray')

# %%
mask_inv.shape
# Out:
# (200, 100)

# %%
white_background = np.full(new2.shape,255,dtype = np.uint8)

# %%
white_background.shape
# Out:
# (200, 100, 3)

# %%
bk = cv2.bitwise_or(white_background,white_background, mask = mask_inv)

# %%
fg = cv2.bitwise_or(new2,new2, mask = mask_inv)

# %%
plt.imshow(fg)

# %%
final_roi =cv2.bitwise_or(roi,fg)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-26-e8ccb0221269> in <module>
# ----> 1 final_roi =cv2.bitwise_or(roi,fg)
#
# error: OpenCV(3.4.1) C:\Miniconda3\conda-bld\opencv-suite_1533128839831\work\modules\core\src\arithm.cpp:225: error: (-209) The operation is neither 'array op array' (where arrays have the same size and type), nor 'array op scalar', nor 'scalar op array' in function cv::binary_op
